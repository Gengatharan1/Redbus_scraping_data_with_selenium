# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"../data/final_backup/final_data.csv")

# %%
df1
# Out:
#        Unnamed: 0                       Bus_name  \
# 0               0              IntrCity SmartBus
# 1               1              IntrCity SmartBus
# 2               2                       FRESHBUS
# 3               3  AdSri Sanvi Tours and Travels
# 4               4                       FRESHBUS
# ...           ...                            ...
# 16286       16286    Baikuntha Transport Service
# 16287       16287           Purple Wings Coaches
# 16288       16288              Shree Ram Travels
# 16289       16289              Christina Travels
# 16290       16290                      Maa Laxmi
#
#                                     Bus_type Start_time End_time  \
# 0         Scania AC Multi Axle Sleeper (2+1)      23:59    06:30
# 1                 A/C Seater / Sleeper (2+1)      23:50    05:35
# 2                  Electric A/C Seater (2+2)      11:00    17:40
# 3                          A/C Sleeper (2+1)      23:00    04:53
# ...

# %%
del df1['Unnamed: 0']

# %%
df1
# Out:
#                             Bus_name                               Bus_type  \
# 0                  IntrCity SmartBus     Scania AC Multi Axle Sleeper (2+1)
# 1                  IntrCity SmartBus             A/C Seater / Sleeper (2+1)
# 2                           FRESHBUS              Electric A/C Seater (2+2)
# 3      AdSri Sanvi Tours and Travels                      A/C Sleeper (2+1)
# 4                           FRESHBUS              Electric A/C Seater (2+2)
# ...                              ...                                    ...
# 16286    Baikuntha Transport Service          Bharat Benz A/C Sleeper (2+1)
# 16287           Purple Wings Coaches             A/C Seater / Sleeper (2+1)
# 16288              Shree Ram Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 16289              Christina Travels                   NON A/C Seater (2+2)
# 16290                      Maa Laxmi         NON A/C Seater Push Back (2+1)
#
# ...

# %%
df1.to_csv("final_bus_data.csv")

# %%
df1['Bus_type'].unique()
# Out:
# array(['Scania AC Multi Axle Sleeper (2+1)', 'A/C Seater / Sleeper (2+1)',
#        'Electric A/C Seater (2+2)', 'A/C Sleeper (2+1)',
#        'Non A/C Seater / Sleeper (2+1)', 'AC Sleeper (2+1)',
#        'Volvo A/C Semi Sleeper (2+2)',
#        'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'Electric A/C Seater/Sleeper (2+1)', 'NON A/C Sleeper (2+1)',
#        'Bharat Benz A/C Sleeper (2+1)', 'NON A/C Seater/ Sleeper (2+1)',
#        'VE A/C Sleeper (2+1)', 'NON A/C Hi-Tech (2+2)',
#        'A/C Volvo B11R Multi-Axle Sleeper (2+1)',
#        'A/C Seater/Sleeper (2+1)', 'Volvo Multi Axle Sleeper B11R (2+1)',
#        'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)',
#        'NON A/C Push Back (2+2)', 'NON AC Seater / Sleeper 2+1',
#        'VE A/C Seater / Sleeper (2+1)',
#        'Volvo 9600 Multi-Axle A/C Sleeper (2+1)',
#        'Scania Multi-Axle AC Semi Sleeper (2+2)',
#        'NON A/C Hi-Tech Push Back (2+2)',
#        'Volvo Multi-Axle Sleeper A/C (2+1)',
# ...

# %%
# Retrieve unique values per column
unique_values = {col: df1[col].unique() for col in df1.columns}

for col, values in unique_values.items():
    print(f"Unique values in column {col}: {values}")
# Out:
# Unique values in column Bus_name: ['IntrCity SmartBus' 'FRESHBUS' 'AdSri Sanvi Tours and Travels' ...
#  'GURUNANAK TRAVELS' 'Slumber 37' 'Shree Ram Travels']
# Unique values in column Bus_type: ['Scania AC Multi Axle Sleeper (2+1)' 'A/C Seater / Sleeper (2+1)'
#  'Electric A/C Seater (2+2)' 'A/C Sleeper (2+1)'
#  'Non A/C Seater / Sleeper (2+1)' 'AC Sleeper (2+1)'
#  'Volvo A/C Semi Sleeper (2+2)' 'Bharat Benz A/C Seater /Sleeper (2+1)'
#  'Electric A/C Seater/Sleeper (2+1)' 'NON A/C Sleeper (2+1)'
#  'Bharat Benz A/C Sleeper (2+1)' 'NON A/C Seater/ Sleeper (2+1)'
#  'VE A/C Sleeper (2+1)' 'NON A/C Hi-Tech (2+2)'
#  'A/C Volvo B11R Multi-Axle Sleeper (2+1)' 'A/C Seater/Sleeper (2+1)'
#  'Volvo Multi Axle Sleeper B11R (2+1)'
#  'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)'
#  'NON A/C Push Back (2+2)' 'NON AC Seater / Sleeper 2+1'
#  'VE A/C Seater / Sleeper (2+1)' 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)'
#  'Scania Multi-Axle AC Semi Sleeper (2+2)'
# ...

# %%
df1[['Origin','Destination']] = df1['Route_name'].str.split(" to ", expand=True)
df1
# Out:
#                             Bus_name                               Bus_type  \
# 0                  IntrCity SmartBus     Scania AC Multi Axle Sleeper (2+1)
# 1                  IntrCity SmartBus             A/C Seater / Sleeper (2+1)
# 2                           FRESHBUS              Electric A/C Seater (2+2)
# 3      AdSri Sanvi Tours and Travels                      A/C Sleeper (2+1)
# 4                           FRESHBUS              Electric A/C Seater (2+2)
# ...                              ...                                    ...
# 16286    Baikuntha Transport Service          Bharat Benz A/C Sleeper (2+1)
# 16287           Purple Wings Coaches             A/C Seater / Sleeper (2+1)
# 16288              Shree Ram Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 16289              Christina Travels                   NON A/C Seater (2+2)
# 16290                      Maa Laxmi         NON A/C Seater Push Back (2+1)
#
# ...

# %%
origin = list(set(df1['Origin'].to_list()))
origin
# Out:
# ['Amritsar',
#  'Gohpur',
#  'Visakhapatnam',
#  'Anantapur (andhra pradesh)',
#  'Ghumarwin',
#  'Jorhat',
#  'Jhargram',
#  'Manali',
#  'Guntur (Andhra Pradesh)',
#  'Thrissur',
#  'Kozhikode',
#  'Chennai',
#  'Mysore',
#  'Sikar',
#  'Dinanagar (punjab)',
#  'Madanapalli',
#  'Ongole',
#  'Khammam',
#  'Chittoor (Andhra Pradesh)',
#  'Muzaffarpur (Bihar)',
#  'Durgapur (West Bengal)',
#  'Narnaul',
#  'Dalhousie',
#  'Amalapuram',
#  'Haflong',
#  'Ernakulam',
#  'Hisar (Haryana)',
#  'Narasaraopet',
#  'Thiruvananthapuram',
#  'Kothagudem',
#  'Rishikesh',
#  'Tinsukia',
#  'Shimla',
#  'Hyderabad',
#  'Hamirpur (Himachal Pradesh)',
#  'Delhi',
#  'Haridwar',
#  'Kolkata',
#  'Siliguri',
#  'Kodad',
#  'Bangalore',
#  'Kota(Rajasthan)',
#  'Kottayam',
#  'Solan',
#  'Rayachoti',
#  'Kishangarh',
#  'Bettiah',
#  'Purnea',
#  'Jodhpur',
#  'Moran',
#  'Pathankot',
#  'Ludhiana',
#  'Vrindavan',
#  'Jaipur (Rajasthan)',
#  'Agra',
#  'Kadiri',
#  'Motihari',
#  'Digha',
# ...

# %%
destination = list(set(df1['Destination'].to_list()))
destination
# Out:
# ['Amritsar',
#  'Visakhapatnam',
#  'Anantapur (andhra pradesh)',
#  'Jorhat',
#  'Bajkul (West Bengal)',
#  'Manali',
#  'Thrissur',
#  'Kozhikode',
#  'Chennai',
#  'Mysore',
#  'Sikar',
#  'Dinanagar (punjab)',
#  'Madanapalli',
#  'Forbesganj',
#  'Ongole',
#  'Chittoor (Andhra Pradesh)',
#  'Nalagarh',
#  'Mechogram',
#  'Muzaffarpur (Bihar)',
#  'Durgapur (West Bengal)',
#  'Dalhousie',
#  'Amalapuram',
#  'Haflong',
#  'Ernakulam',
#  'Sarkaghat',
#  'Hisar (Haryana)',
#  'Narasaraopet',
#  'Thiruvananthapuram',
#  'Katihar',
#  'Kothagudem',
#  'Rishikesh',
#  'Tinsukia',
#  'Araria (Bihar)',
#  'Malda',
#  'Shimla',
#  'Pilani',
#  'Hyderabad',
#  'Hamirpur (Himachal Pradesh)',
#  'Delhi',
#  'Warangal',
#  'Haridwar',
#  'Kolkata',
#  'Siliguri',
#  'Kolaghat',
#  'Bangalore',
#  'Kota(Rajasthan)',
#  'Kottayam',
#  'Solan',
#  'Rayachoti',
#  'Bettiah',
#  'Purnea',
#  'Jodhpur',
#  'Heria',
#  'Pathankot',
#  'Vrindavan',
#  'Ludhiana',
#  'Moran',
#  'Contai (Kanthi)',
# ...

# %%
data = {
    "Origin": origin
}

# %%
origin_df = pd.DataFrame(data)
origin_df
# Out:
#                          Origin
# 0                      Amritsar
# 1                        Gohpur
# 2                 Visakhapatnam
# 3    Anantapur (andhra pradesh)
# 4                     Ghumarwin
# ..                          ...
# 119    Berhampore (West Bengal)
# 120                       Habra
# 121                     Kurnool
# 122                      Dhubri
# 123     Aligarh (uttar pradesh)
#
# [124 rows x 1 columns]

# %%
origin_df.to_csv("origin.csv", index= False)

# %%
data = {
    "destination": destination
}

# %%
destination_df = pd.DataFrame(data)
destination_df
# Out:
#                     destination
# 0                      Amritsar
# 1                 Visakhapatnam
# 2    Anantapur (andhra pradesh)
# 3                        Jorhat
# 4          Bajkul (West Bengal)
# ..                          ...
# 147                      Dhubri
# 148                    Bakkhali
# 149                  Mancherial
# 150     Aligarh (uttar pradesh)
# 151                      Nirmal
#
# [152 rows x 1 columns]

# %%
destination_df.to_csv("destination.csv", index= False)

# %%
states = ['TN', 'Kerala']

# Open a file in write mode
with open('states.py', 'w') as file:
    # Write content to the file
    file.write('states = '+str(states))

# %%
from states import states
states
# Out:
# ['TN', 'Kerala']
