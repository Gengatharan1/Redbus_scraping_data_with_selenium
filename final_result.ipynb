# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\IT\github\redbus_scraping_filtering\csv_files\final_backup\final_data.csv")

# %%
df1
# Out:
#        Unnamed: 0                       Bus_name  \
# 0               0              IntrCity SmartBus
# 1               1              IntrCity SmartBus
# 2               2                       FRESHBUS
# 3               3  AdSri Sanvi Tours and Travels
# 4               4                       FRESHBUS
# ...           ...                            ...
# 16286       16286    Baikuntha Transport Service
# 16287       16287           Purple Wings Coaches
# 16288       16288              Shree Ram Travels
# 16289       16289              Christina Travels
# 16290       16290                      Maa Laxmi
#
#                                     Bus_type Start_time End_time  \
# 0         Scania AC Multi Axle Sleeper (2+1)      23:59    06:30
# 1                 A/C Seater / Sleeper (2+1)      23:50    05:35
# 2                  Electric A/C Seater (2+2)      11:00    17:40
# 3                          A/C Sleeper (2+1)      23:00    04:53
# ...

# %%
del df1['Unnamed: 0']

# %%
df1
# Out:
#                             Bus_name                               Bus_type  \
# 0                  IntrCity SmartBus     Scania AC Multi Axle Sleeper (2+1)
# 1                  IntrCity SmartBus             A/C Seater / Sleeper (2+1)
# 2                           FRESHBUS              Electric A/C Seater (2+2)
# 3      AdSri Sanvi Tours and Travels                      A/C Sleeper (2+1)
# 4                           FRESHBUS              Electric A/C Seater (2+2)
# ...                              ...                                    ...
# 16286    Baikuntha Transport Service          Bharat Benz A/C Sleeper (2+1)
# 16287           Purple Wings Coaches             A/C Seater / Sleeper (2+1)
# 16288              Shree Ram Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 16289              Christina Travels                   NON A/C Seater (2+2)
# 16290                      Maa Laxmi         NON A/C Seater Push Back (2+1)
#
# ...

# %%
df1[['Origin','Destination']] = df1['Route_name'].str.split(" to ", expand=True)

# %%
origin = list(set(df1['Origin'].to_list()))
origin
# Out:
# ['Kadapa',
#  'Kottayam',
#  'Siliguri',
#  'Dehradun',
#  'Dalhousie',
#  'Thiruvananthapuram',
#  'Aligarh (uttar pradesh)',
#  'Beawar (Rajasthan)',
#  'Berhampore (West Bengal)',
#  'Eluru',
#  'Bettiah',
#  'Tezpur',
#  'Patna (Bihar)',
#  'Kakinada',
#  'Bangalore',
#  'Dinanagar (punjab)',
#  'Kodad',
#  'Ludhiana',
#  'Hisar (Haryana)',
#  'Kangra',
#  'Kothagudem',
#  'Biswanath Charali',
#  'Midnapore',
#  'Delhi',
#  'Sujanpur (himachal pradesh)',
#  'Rajahmundry',
#  'Haflong',
#  'Kishangarh',
#  'Jammu (j and k)',
#  'Kadiri',
#  'Ernakulam',
#  'Motihari',
#  'Narnaul',
#  'Jorhat',
#  'Rishikesh',
#  'Coimbatore',
#  'Baddi (Himachal Pradesh)',
#  'Haldia',
#  'Muzaffarpur (Bihar)',
#  'Shimla',
#  'Darbhanga',
#  'Hyderabad',
#  'Visakhapatnam',
#  'Jagityal',
#  'Palampur',
#  'Anantapur (andhra pradesh)',
#  'Kozhikode',
#  'Burdwan',
#  'Talwara',
#  'Chittoor (Andhra Pradesh)',
#  'Kota(Rajasthan)',
#  'Asansol (West Bengal)',
#  'Kurnool',
#  'Chandigarh',
# ...

# %%
destination = list(set(df1['Destination'].to_list()))
destination
# Out:
# ['Kadapa',
#  'Kottayam',
#  'Siliguri',
#  'Dehradun',
#  'Dalhousie',
#  'Thiruvananthapuram',
#  'Aligarh (uttar pradesh)',
#  'Beawar (Rajasthan)',
#  'Berhampore (West Bengal)',
#  'Bettiah',
#  'Tezpur',
#  'Patna (Bihar)',
#  'Kakinada',
#  'Bangalore',
#  'Dinanagar (punjab)',
#  'Reckong Peo (Himachal Pradesh)',
#  'Bhadrachalam',
#  'Ludhiana',
#  'Kangra',
#  'Hisar (Haryana)',
#  'Haldwani',
#  'Kothagudem',
#  'Mancherial',
#  'Nirmal',
#  'Futishanko',
#  'Midnapore',
#  'Debra',
#  'Delhi',
#  'Biswanath Charali',
#  'Sujanpur (himachal pradesh)',
#  'Rajahmundry',
#  'Warangal',
#  'Hajipur (Bihar)',
#  'Haflong',
#  'Jammu (j and k)',
#  'Kadiri',
#  'Pilani',
#  'Ernakulam',
#  'Bharatpur',
#  'Motihari',
#  'Jorhat',
#  'Araria (Bihar)',
#  'Rishikesh',
#  'Baddi (Himachal Pradesh)',
#  'Haldia',
#  'Muzaffarpur (Bihar)',
#  'Shimla',
#  'Sarkaghat',
#  'Hyderabad',
#  'Visakhapatnam',
#  'Palampur',
#  'Anantapur (andhra pradesh)',
#  'Kozhikode',
#  'Armoor',
# ...

# %%
data = {
    "Origin": origin
}

# %%
origin_df = pd.DataFrame(data)
origin_df
# Out:
#         Origin
# 0       Kadapa
# 1     Kottayam
# 2     Siliguri
# 3     Dehradun
# 4    Dalhousie
# ..         ...
# 119      Solan
# 120      Habra
# 121  Dibrugarh
# 122     Kannur
# 123   Tirupati
#
# [124 rows x 1 columns]

# %%
origin_df.to_csv(r"C:\IT\github\redbus_scraping_filtering\csv_files\final_backup\origin.csv", index= False)

# %%
data = {
    "destination": destination
}

# %%
destination_df = pd.DataFrame(data)
destination_df
# Out:
#     destination
# 0        Kadapa
# 1      Kottayam
# 2      Siliguri
# 3      Dehradun
# 4     Dalhousie
# ..          ...
# 147       Solan
# 148       Habra
# 149   Dibrugarh
# 150      Kannur
# 151    Tirupati
#
# [152 rows x 1 columns]

# %%
destination_df.to_csv(r"C:\IT\github\redbus_scraping_filtering\csv_files\final_backup\destination.csv", index= False)
